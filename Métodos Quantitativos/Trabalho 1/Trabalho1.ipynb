# %%
import pandas as pd
df = pd.read_csv("../DataSet/outdoor40.csv")
df.head()
# Out:
#    actualDist  rttRaw  estDistRaw  absErrRaw  rttEst  estDistEst  absErrEst  \
# 0           1       5    0.749481   0.250519       0         0.0        1.0
# 1           1       5    0.749481   0.250519       0         0.0        1.0
# 2           1       5    0.749481   0.250519       0         0.0        1.0
# 3           1       4    0.599585   0.400415       0         0.0        1.0
# 4           1       4    0.599585   0.400415       0         0.0        1.0
#
#      varRtt  meanRtt  countRtt  meanRss  distEst
# 0  2.839286    5.375         8    -66.0      0.0
# 1  2.785714    5.750         8    -66.0      0.0
# 2  0.982143    5.125         8    -66.0      0.0
# 3  1.000000    5.000         7    -66.0      0.0
# 4  2.696429    5.125         8    -66.0      0.0

# %%
df.describe()
# Out:
#         actualDist       rttRaw   estDistRaw    absErrRaw       rttEst  \
# count  3139.000000  3139.000000  3139.000000  3139.000000  3139.000000
# mean     10.372730    78.619943    11.784833     1.456713    60.804715
# std       5.728561    41.412703     6.207608     0.856879    37.910268
# min       1.000000     3.000000     0.449689     0.002075     0.000000
# 25%       5.000000    43.000000     6.445538     0.848028    28.000000
# 50%      10.000000    79.000000    11.841802     1.385887    59.000000
# 75%      15.000000   114.000000    17.088170     1.940349    90.000000
# max      20.000000   162.000000    24.283189     6.539934   136.000000
#
#         estDistEst    absErrEst       varRtt      meanRtt     countRtt  \
# count  3139.000000  3139.000000  3139.000000  3139.000000  3139.000000
# mean      9.114397     1.351726    79.635487    79.127334     7.684294
# std       5.682606     0.662475   154.891540    41.425581     0.718537
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(df['actualDist'], df['estDistEst'])
plt.xlabel('actualDist')
plt.ylabel('estDistEst')
plt.title('Scatter plot of actualDist vs estDistEst')
plt.show()
